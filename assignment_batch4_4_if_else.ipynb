# %% [markdown]
# ### 1. Write a program to check if a number is positive.

# %%
num=int(input("enter the number"))
if num>0:
    print(f"{num} is positive")
else:
    print(f"{num} is negative")
# Out:
# 6 is positive

# %% [markdown]
# ### 2. Check if a number is even or odd.

# %%
num=int(input("enter number"))
if num%2==1:
    print(f"{num} is odd")
else:
    print(f"{num} is even")
# Out:
# 5 is odd

# %% [markdown]
# ### 3. Check if a person is eligible to vote (age >= 18).

# %%
num=int(input("enter number :"))
if num>=18:
    print(f"{num} Eligible")
else:
    print(f"{num} Not Eligible")
# Out:
# 57 Eligible

# %% [markdown]
# ### 4. Check if a number is greater than 100.

# %%
num=int(input("enter number"))
if num>100:
    print(f"{num} greater than 100")
else:
    print(f"{num} less than 100")
# Out:
# 101 greater than 100

# %% [markdown]
# ### 5. Print “Adult” if age > 18 else print “Child”.

# %%
num=int(input("enter number"))
if num>=18:
    print("Adult")
else:
    print("child")
# Out:
# Adult

# %% [markdown]
# ### 6. Check if two numbers are equal.

# %%
num=int(input("enter number1"))
num1=int(input("enter number2"))
if num==num1:
    print("is equal")
else:
    print("not equal")
# Out:
# not equal

# %% [markdown]
# ### 7. Check if a number is divisible by 5.

# %%
num=int(input("enter number"))
if num%5==0:
    print(f"{num} divisible by 5")
else:
    print(f"{num} not divisible by 5")
# Out:
# 30 divisible by 5

# %% [markdown]
# ### 8. Check if a string is “hello”.

# %%
text=(input("enter a word"))
if text=="hello":
    print("hello")
else:
    print("not hello")
# Out:
# not hello

# %% [markdown]
# ### 9. Print the larger of two numbers.

# %%
num1=int(input("enter a num1"))
num2=int(input("enter a num2"))
if num1>num2:
    print(f"{num1} is larger")
else :
    print(f"{num2} is larger")
# Out:
# 95 is larger

# %% [markdown]
# ### 10. Check if a number is negative

# %%
num=int(input("enter a number"))
if num<0:
    print(f"{num} is Negative")
else:
    print(f"{num} is Positive")
# Out:
# -6 is Negative

# %% [markdown]
# ### 11. Check if a number is positive, negative, or zero.

# %%
num=int(input("enter a number"))
if num<0:
    print("num is Negative")
elif num==0:
    print("its zero")
else:
    print("num is positive")
# Out:
# num is Negative

# %% [markdown]
# ### 12. Check if a year is a leap year.

# %%
year=int(input("enter a Year"))
if year%400==0:
    print(f"{year} is leap Year")
elif year%100==0:
    print(f"{year} not leap Year")
elif year%4==0:
    print(f"{year} is leap Year")
else:
    print(f"{year} is not leap Year")
# Out:
# 2000 is leap Year

# %% [markdown]
# ### 13. Check if a character is a vowel or consonant.

# %%
v=input("enter a word").lower()
vowels=["a","e","i","o","u"]
if v in vowels:
    print(f"{v} is vowels")
else:
    print(f"{v} is consonant")
# Out:
# u is vowels

# %% [markdown]
# ### 14. Print the greatest of three numbers.

# %%
num1=int(input("enter number1"))
num2=int(input("enter number2"))
num3=int(input("enter number3"))
if num1>num2 and num1>num3:
    print(f"{num1} is greater")
elif num2>num3 and num2>num1:
    print(f"{num2} is greater")
else:
    print(f"{num3} is greater")
# Out:
# 100 is greater

# %% [markdown]
# ### 15. Check if a password length is strong (>= 8).

# %%
password=input("enter password")
if len(password)>=8:
    print(f"{password}  password is Strong")
else:
    print(f"{password}  password is not strong")
# Out:
# ;lkajsdfkajsdf  password is Strong

# %% [markdown]
# ### 16. Check if a number lies between 10 and 50.

# %%
num=int(input("enter a number"))
if num in range(10,51):
    print(f"{num} is between 10 and 50")
else:
    print(f"{num} is not in 10 and 50")

# %%
num=int(input("enter a number"))
if num>10 and num <50:
    print(f"{num} is between 10and 50")
else:
    print(f"{num} not in 10 and 50")
# Out:
# 51 not in 10 and 50

# %% [markdown]
# ### 17. Print the grade of a student (A, B, C, D, F) based on marks.

# %%
num=int(input("enter marks"))
if num>90:
    print("grade A")
elif 90>num>80:
      print("grade B")
elif 80>num>70:
       print("grade c")
elif 70>num>60:
        print("grade D")
else:
        print("grade F")
# Out:
# grade c

# %% [markdown]
# ### 18. Check if a number is divisible by both 2 and 3.

# %%
num=int(input("enter a number"))
if num%2==0 and num%3==0:
    print(f"{num} numberr is devided by 2 and 3")
else:
    print(f"{num} is not devide by both 2 and 3")
# Out:
# 659 is not devide by both 2 and 3

# %% [markdown]
# ### 19. Check if a person’s age falls into categories: child, teen, adult, senior.

# %%
num=int(input("enter marks"))
if num<18:
    print("person is child")
if 30>num>18:
    print("person is teen")
elif 50>num>30:
      print("person is adult")
else:
       print("person is senior")
# Out:
# person is senior

# %% [markdown]
# ### 20. Check if a character is uppercase or lowercase.

# %%
char=input("enter character")
if char.isupper():
    print("upper case")
elif char.islower():
    print("lower case")
else:
    print("not a alphabet")
# Out:
# not a alphabet

# %% [markdown]
# ### 21. Check if a number is a multiple of 10.

# %%
num=int(input("enter number"))
if num%10==0:
    print(f"{num} is devisible by 10")
else:
    print(f"{num} is not devisible by 10")
# Out:
# 20 is devisible by 10

# %% [markdown]
# ### 22. Compare two numbers and print “greater”, “smaller”, or “equal”.

# %%
num1=int(input("enter number1"))
num2=int(input("enter number2"))
if num1>num2:
    print(f"{num1} is greater and {num2} is smaller")
elif num2>num1:
        print(f"{num2} is greater and {num1} is smaller")
else:
           print("both numbers are equal")
# Out:
# both numbers are equal

# %% [markdown]
# 23. Check if a triangle is equilateral, isosceles, or scalene.

# %% [markdown]
# ### 24. Check if a string contains the word “python”.

# %%
char=["python","amey","mayur"]
"python" in char
# Out:
# True

# %% [markdown]
# ### 25. Check if a list has more than 5 elements.

# %%
num=[1,2,3,4,5,6,45,87]
if len(num)>5:
    print("elements are more than 5")
else:
        print("elements are less than 5")
# Out:
# elements are more than 5

# %% [markdown]
# ### 26. Check if temperature is cold (<15), warm (15–30), or hot (>30).

# %%
temp=int(input("enter temp:"))
if temp<15:
    print(f"{temp} degree temp is cold")
elif temp in range(15,31):
        print(f"{temp} degree temp is warm")
else:
          print(f"{temp} degree temp is hot")
# Out:
# -5 degree temp is cold

# %% [markdown]
# ### 27. Check if a student passed (marks >= 40) else fail.

# %%
marks=int(input("enter a marks"))
if marks>=40:
    print("student is pass")
else:
    print("student is fail")
# Out:
# student is pass

# %% [markdown]
# ### 28. Check if a number ends with digit 7.

# %%
num=int(input("enter a number"))
if num%10==7:
    print("number ends with 7")
else:
    print("number is not ends with 7")
# Out:
# number ends with 7

# %% [markdown]
# ### 29. Check if the first character of a string is a vowel.

# %%
char=input("enter a character")
vowels="aeiouAEIOU"
if char[0] in vowels:
    print("character is starts with vowels")
else:
        print("character is not starts with vowels")
# Out:
# character is not starts with vowels

# %% [markdown]
# ### 30. Check if a number is within 1 to 100, else print “out of range

# %%
num=int(input("enter a number"))
if num in range(1,101):
    print("in range")
else:
    print("not in range")
# Out:
# not in range

# %% [markdown]
# ### 31. Check if a number is prime using if-else (simple logic allowed).

# %%
num=int(input("enter a number:"))
if num<=1:
    print("not prime number")
else:
    for i in range(2,num):
        if num%i==0:
            print("its not a prime numbe")
            break
    else:
        print("its a prime number")
# Out:
# its a prime number

# %% [markdown]
# ### 32. Check if the last digit of a number is even or odd.

# %%
num=int(input("enter a number"))
even=[0,2,4,6,8]
if num%10 in even:
    print("last degit is even")
else:
    print("last digit is odd")
# Out:
# last degit is even

# %%
num=int(input("enter a number"))
last=num%10
if last%2==0:
    print("last degit is even")
else:
    print("last digit is odd")
# Out:
# last digit is odd

# %% [markdown]
# ### 33. Check if the input is an integer or not (using string checks).

# %%
num=input("enter")
if num.isdigit():
    print("int")
else:
    if num.startswith("-") and num[1:].isdigit():
        print("int")
    else:
        print("not int")
# Out:
# str

# %% [markdown]
# ### 34. Check if three angles can form a valid triangle.

# %%
A=int(input("enter a number"))
B=int(input("enter a number"))
C=int(input("enter a number"))
if A+B+C==180:
    print("angles are eligible to make valid triangle")
else:
    print("angles are not valid")
# Out:
# angles are not valid

# %% [markdown]
# ### 35. Check if two strings are anagrams (simple: check sorted equality).

# %%
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

# Remove spaces and convert to lowercase
str1 = str1.replace(" ", "").lower()
str2 = str2.replace(" ", "").lower()

if sorted(str1) == sorted(str2):
    print("Both strings are anagrams")                              ######## not understand this syntax #######
else:
    print("Strings are NOT anagrams")
# Out:
# Both strings are anagrams

# %% [markdown]
# ### 36. Determine the type of triangle using sides: acute, right, obtuse.

# %% [markdown]
# ### 37. Check if a string is palindrome (case insensitive).

# %% [markdown]
# ### 38. Check if the first and last characters of a string are same.

# %% [markdown]
# ### 39. Check if the sum of digits of a number is divisible by 3.

# %%
num=int(input("enter num"))
if num%3==0:
    print("devisible by 3")
else:
    print("not devisible by 3")
# Out:
# devisible by 3

# %% [markdown]
# ### 40. Check if a number is Armstrong (3-digit).

# %% [markdown]
# ### 41. Check if a number has exactly 3 digits.

# %%
num=int(input("enter num"))
if 100 <= num <= 999:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# ### 42. Check if a number is perfect (sum of factors equals number).

# %% [markdown]
# ### 43. Compare lengths of two strings and print which is longer.

# %%
char1=input("enter str")
char2=input("enter str")
if len(char1)>len(char2):
    print("char1 is longer")
else:
    print("char2 is longer")
# Out:
# char2 is longer

# %% [markdown]
# ### 44. Check if a list contains duplicates.

# %% [markdown]
# ### 45. Check if a number is both prime AND even (only possible is 2).

# %%
num=int(input("Enter a number: "))
if num==2:
    print("Number is prime and even")
else:
    print("Not prime and even")     #num=2
# Out:
# Number is prime and even

# %% [markdown]
# ### 46. Print “YES” if any of the two numbers is zero else print “NO”.

# %%
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
if a==0 or b==0:
    print("YES")
else:
    print("NO")         #a=0,b=0
# Out:
# YES

# %% [markdown]
# ### 47. Check if two numbers have the same last digit.

# %%
a=int(input("First number: "))
b=int(input("Second number: "))
if a%10==b%10:
    print("Same last digit")
else:
    print("Different last digit")       #a=20,b=30
# Out:
# Same last digit

# %% [markdown]
# ### 48. Check if a password contains both letters and digits.

# %%
password = input("Enter password: ")
if any(c.isdigit() for c in password) and any(c.isalpha() for c in password):
    print("Valid password")
else:
    print("Invalid password")           #password=amey1720
# Out:
# Valid password

# %% [markdown]
# ### 49. Check if a number is “lucky”: sum of first two digits equals last two digits.

# %%
num=input("Enter 4-digit number: ")
if len(num)==4 and (int(num[:2])==int(num[2:])):
    print("Lucky number")
else:
    print("Not lucky")          #num=3434
# Out:
# Lucky number

# %% [markdown]
# ### 50. Check if the absolute difference between two numbers is less than 10

# %%
a=int(input("1st number: "))
b=int(input("2nd number: "))
if abs(a-b)<10:
    print("Difference less than 10")
else:
    print("Difference 10 or more")      #a=4,b=2
# Out:
# Difference less than 10

# %% [markdown]
# ### 51. Write a program to check if a variable is an integer using isinstance().

# %%
var=10
if isinstance(var, int):
    print("Integer found")
else:
    print("Not an integer")
# Out:
# Integer found

# %% [markdown]
# ### 52. Check if a given input is a string using isinstance().

# %%
var = "hello"
if isinstance(var, str):
    print("String found")
else:
    print("Not a string")
# Out:
# String found

# %% [markdown]
# ### 53. Check if a variable is a float and print “Float value found”.

# %%
var = 5.5
if isinstance(var, float):
    print("Float value found")
else:
    print("Not float")
# Out:
# Float value found

# %% [markdown]
# ### 54. Check if a variable is a list; if yes, print its length.

# %%
var = [1,2,3]
if isinstance(var, list):
    print("Length of list:", len(var))
else:
    print("Not a list")
# Out:
# Length of list: 3

# %% [markdown]
# ### 55. Write a program to check if a variable is a tuple; if yes, print the first element.

# %%
var = (10, 20, 30)
if isinstance(var, tuple):
    print("First element:", var[0])
else:
    print("Not a tuple")
# Out:
# First element: 10

# %% [markdown]
# ### 56. Check if a variable is a dictionary; if yes, print all keys.

# %%
var = {"a":1, "b":2}
if isinstance(var, dict):
    print("Keys:", list(var.keys()))
else:
    print("Not a dictionary")
# Out:
# Keys: ['a', 'b']

# %% [markdown]
# ### 57. Check if a variable is a set; if yes, print the number of elements.

# %%
var = {1,2,3}
if isinstance(var, set):
    print("Number of elements:", len(var))
else:
    print("Not a set")
# Out:
# Number of elements: 3

# %% [markdown]
# ### 58. Check if a variable is a boolean and print “True/False detected”.

# %%
var = True
if isinstance(var, bool):
    print("Boolean detected")
else:
    print("Not a boolean")
# Out:
# Boolean detected

# %% [markdown]
# ### 59. Write a program to check if a variable is either int OR float (number check).

# %%
var = 5.5
if isinstance(var, (int, float)):
    print("Variable is a number")
else:
    print("Not a number")
# Out:
# Variable is a number

# %% [markdown]
# ### 60. Check if a variable is NOT a list (using not isinstance()), and print: “Not a list”.

# %%
var = 10
if not isinstance(var, list):
    print("Not a list")
else:
    print("It is a list")
# Out:
# Not a list
